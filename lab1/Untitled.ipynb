# %% [markdown]
# # Лабораторная работа 1
#
#                по теме
#
# **Многоклассовая классификация цветов**
#
# Выполнил студент
#
# Группы БСТ1801
#
# Харатишвили Заза

# %% [markdown]
# ## Архитектура ИНС №1
#
# В листинге 1 представлен код программы с базовой архихтектурой сети из двух слоев и установленными в методическом указании параметрами обучения.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.cvs", header=None)
dataset = dataframe.values

X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

dummy_y = to_categorical(encoded_Y)

model1 = Sequential()
model1.add(Dense(4, activation='relu'))
model1.add(Dense(3, activation='softmax'))

model1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
out1 = model1.fit(X, dummy_y, epochs=75, batch_size=10, validation_split=0.1)

loss = out1.history['loss']
val_loss = out1.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(out1.history['accuracy'], 'g', label='Training acc')
plt.plot(out1.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(out1.history['loss'], 'g', label='Training loss')
plt.plot(out1.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/75
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1322 - accuracy: 0.3704 - val_loss: 1.0117 - val_accuracy: 0.0000e+00
# Epoch 2/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1087 - accuracy: 0.3704 - val_loss: 1.0026 - val_accuracy: 0.0000e+00
# Epoch 3/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0914 - accuracy: 0.3704 - val_loss: 0.9989 - val_accuracy: 0.0000e+00
# Epoch 4/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0785 - accuracy: 0.3704 - val_loss: 0.9934 - val_accuracy: 0.0000e+00
# Epoch 5/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0690 - accuracy: 0.3704 - val_loss: 0.9916 - val_accuracy: 0.0000e+00
# Epoch 6/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0613 - accuracy: 0.3704 - val_loss: 0.9951 - val_accuracy: 0.0000e+00
# Epoch 7/75
# ...

# %% [markdown]
# ## Архитектура ИНС №2
#
# В листинге 2 представлен код программы с базовой архихтектурой сети из трех слоев и установленными в методическом указании параметрами обучения.

# %%
model2 = Sequential()
model2.add(Dense(5, activation='sigmoid'))
model2.add(Dense(4, activation='relu'))
model2.add(Dense(3, activation='softmax'))

model2.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
out2 = model2.fit(X, dummy_y, epochs=75, batch_size=10, validation_split=0.1)

plt.plot(out2.history['accuracy'], 'g', label='Training acc')
plt.plot(out2.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(out2.history['loss'], 'g', label='Training loss')
plt.plot(out2.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/75
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1272 - accuracy: 0.3704 - val_loss: 1.1249 - val_accuracy: 0.0000e+00
# Epoch 2/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1223 - accuracy: 0.3704 - val_loss: 1.1350 - val_accuracy: 0.0000e+00
# Epoch 3/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1176 - accuracy: 0.3704 - val_loss: 1.1422 - val_accuracy: 0.0000e+00
# Epoch 4/75
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1140 - accuracy: 0.3704 - val_loss: 1.1476 - val_accuracy: 0.0000e+00
# Epoch 5/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1105 - accuracy: 0.3704 - val_loss: 1.1560 - val_accuracy: 0.0000e+00
# Epoch 6/75
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1073 - accuracy: 0.3704 - val_loss: 1.1624 - val_accuracy: 0.0000e+00
# Epoch 7/75
# ...

# %% [markdown]
# ## Архитектура ИНС №3
#
# В листинге 3 представлен код программы с базовой архихтектурой сети из двух слоев и измененными параметрами обучения.

# %%
model3 = Sequential()
model3.add(Dense(4, activation='relu'))
model3.add(Dense(3, activation='softmax'))

model3.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
out3 = model3.fit(X, dummy_y, epochs=150, batch_size=15, validation_split=0.3)

plt.plot(out3.history['accuracy'], 'g', label='Training acc')
plt.plot(out3.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(out3.history['loss'], 'g', label='Training loss')
plt.plot(out3.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.6306 - accuracy: 0.2952 - val_loss: 6.3216 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5251 - accuracy: 0.0571 - val_loss: 6.1172 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4396 - accuracy: 0.0000e+00 - val_loss: 5.9033 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3775 - accuracy: 0.0000e+00 - val_loss: 5.6990 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3335 - accuracy: 0.0000e+00 - val_loss: 5.5203 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2977 - accuracy: 0.0095 - val_loss: 5.3607 - val_accuracy: 0.0000e+00
# Epoch 7/150
# ...

# %% [markdown]
# ## Архитектура ИНС №4
#
# В листинге 3 представлен код программы с базовой архихтектурой сети из трех слоев и измененными параметрами обучения.

# %%
model4 = Sequential()
model4.add(Dense(5, activation='sigmoid'))
model4.add(Dense(4, activation='relu'))
model4.add(Dense(3, activation='softmax'))

model4.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
out4 = model4.fit(X, dummy_y, epochs=150, batch_size=15, validation_split=0.3)

plt.plot(out4.history['accuracy'], 'g', label='Training acc')
plt.plot(out4.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(out4.history['loss'], 'g', label='Training loss')
plt.plot(out4.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/150
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0245 - accuracy: 0.4762 - val_loss: 1.4459 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0128 - accuracy: 0.4762 - val_loss: 1.4768 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0022 - accuracy: 0.4762 - val_loss: 1.5056 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9924 - accuracy: 0.4762 - val_loss: 1.5365 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9826 - accuracy: 0.4762 - val_loss: 1.5676 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9730 - accuracy: 0.4762 - val_loss: 1.5995 - val_accuracy: 0.0000e+00
# Epoch 7/150
# ...

# %%
plt.plot(out1.history['accuracy'], label='First model')
plt.plot(out2.history['accuracy'], label='Second model')
plt.plot(out3.history['accuracy'], label='Third model')
plt.plot(out4.history['accuracy'], label='Fourth model')
plt.title('Comparison of training accuracy')
plt.legend()
plt.show()

plt.plot(out1.history['val_accuracy'], label='First model')
plt.plot(out2.history['val_accuracy'], label='Second model')
plt.plot(out3.history['val_accuracy'], label='Third model')
plt.plot(out4.history['val_accuracy'], label='Fourth model')
plt.title('Comparison of validation accuracy')
plt.legend()
plt.show()

# %%
plt.plot(out1.history['loss'], label='First model')
plt.plot(out2.history['loss'], label='Second model')
plt.plot(out3.history['loss'], label='Third model')
plt.plot(out4.history['loss'], label='Fourth model')
plt.title('Comparison of training loss')
plt.legend()

plt.figure()

plt.plot(out1.history['val_loss'], label='First model')
plt.plot(out2.history['val_loss'], label='Second model')
plt.plot(out3.history['val_loss'], label='Third model')
plt.plot(out4.history['val_loss'], label='Fourth model')
plt.title('Comparison of validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Вывод
#
# В результате анализа четырех архитектур ИНС наилучшим образом себя показала N модель, учитывая
